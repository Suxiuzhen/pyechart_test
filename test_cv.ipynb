# %%
import cv2
from matplotlib import pyplot as plt

# %%
img_path = './ng_image/dog.jpg'

# %%
img = cv2.imread(img_path)
img = img[:,:, ::-1]
plt.imshow(img)

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray_img,cmap='gray')

# %%
equalized_img = cv2.equalizeHist(gray_img)
plt.imshow(equalized_img,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29288\145212947.py in <module>
# ----> 1 equalized_img = cv2.equalizeHist(gray_img)
#       2 plt.imshow(equalized_img,cmap='gray')
#
# NameError: name 'cv2' is not defined

# %%
minmax_img = cv2.normalize(gray_img, None, 0, 255, cv2.NORM_MINMAX)
plt.imshow(minmax_img,cmap='gray')

# %%
color_enhanced_img = cv2.cvtColor(minmax_img, cv2.COLOR_GRAY2BGR)
plt.imshow(color_enhanced_img,cmap='gray')

# %%
cv2.waitKey()
